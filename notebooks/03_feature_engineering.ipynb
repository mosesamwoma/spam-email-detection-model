# %%
"""
# 03 - Feature Engineering
Goal: Convert text into numeric features using TF-IDF.
"""
# Out:
# '\n# 03 - Feature Engineering\nGoal: Convert text into numeric features using TF-IDF.\n'

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib

# %%
data = pd.read_csv(
    r"C:\Users\Moses Tumbo\OneDrive\Documents\model\tic-tac-toe\data\spam.csv",
    encoding='latin-1'
)

# %%
# Print shape
print("Data shape:", data.shape)
# Out:
# Data shape: (5569, 3)

# %%
# --- Save cleaned dataset ---
data.to_csv(
    r"C:\Users\Moses Tumbo\OneDrive\Documents\model\tic-tac-toe\data\spam.csv",
    index=False,
    encoding='latin-1'
)
print("✅ Saved cleaned dataset with latin-1 encoding.")
# Out:
# ✅ Saved cleaned dataset with latin-1 encoding.
