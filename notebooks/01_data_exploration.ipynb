# %%
# --- TITLE (Markdown) ---
"""
# 01 - Data Exploration
Goal: Understand the dataset (columns, missing values, spam vs ham ratio, text lengths).
"""

# %%
# --- Import libraries ---
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(
    r"C:\Users\Moses Tumbo\OneDrive\Documents\model\tic-tac-toe\data\spam.csv",
    encoding='latin-1'
)
data.head()
# Out:
#      v1  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                             v2  \
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# ...

# %%
# --- Check dataset structure ---
print(data.shape)
print(data.columns)
data.info()
# Out:
# (5572, 5)
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# --- Check missing values ---
data.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
# --- Rename columns if needed ---
data = data.rename(columns={"v1":"label", "v2":"text"})
data = data[['label','text']]

# %%
# --- Inspect class distribution ---
data['label'].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
# --- Visualize class distribution ---
sns.countplot(x=data['label'])
plt.title("Spam vs Ham Distribution")
plt.show()

# %%
# --- Explore text length ---
data['length'] = data['text'].str.len()

sns.histplot(data['length'], bins=50)
plt.title("Message Length Distribution")
plt.show()

# %%
# --- Sample messages ---
print("SPAM:")
print(data[data['label']=="spam"]['text'].sample(3))

print("\nHAM:")
print(data[data['label']=="ham"]['text'].sample(3))
# Out:
# SPAM:
# 1374    500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY å£1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 TXTAUCTION
# 689                                                <Forwarded from 448712404000>Please CALL 08712404000 immediately as there is an urgent message waiting for you.
# 1792                          WIN: We have a winner! Mr. T. Foley won an iPod! More exciting prizes soon, so keep an eye on ur mobile or visit www.win-82050.co.uk
# Name: text, dtype: object
#
# HAM:
# 2569                  Ultimately tor motive tui achieve korli.
# 3524     I not free today i haf 2 pick my parents up tonite...
# 3675    Hey r Ì_ still online? I've finished the formatting...
# Name: text, dtype: object
